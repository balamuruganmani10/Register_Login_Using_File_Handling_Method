# %%
import re

def signup():
    email = input("Enter Email Address : ")
    if email_validation(email) == True:
        pwd = input("Enter Password : ")
        conf_pwd = input("Confirm password : ")
        if conf_pwd == pwd:
            if password_validation(pwd) == True:
                with open("credentials.txt", "w") as f:
                      f.write(email + "\n") 
                      f.write(pwd)
                f.close()
                print("You have registered successfully! ")
            else:
                print("Password doesn't meet their requirements ")
        else:
            print("Password and Confirm Password doesn't match ")
    else:
        print("Enter Valid Email Address ")


def email_validation(email): # Email Validation Function
  x = re.findall(r"^[a-bA-z]+[0-9a-zA-Z]+@[a-zA-z]+.[a-zA-Z]+$",email)
  if x :
        return True
  else:
        return False

def password_validation(password): # Password Validation Function
    special_char = ['$', '@', '#', '%']
    pas = False
    if len(password)>5 and len(password)<16: pas = True
        
    if not any([i.isdigit() for i in password]):
        pas = False
    if not any([i.islower() for i in password]):
        pas = False 
    if not any([i.isupper() for i in password]):
        pas = False 
    if not any([i.isalpha() for i in password]):
        pas = False
    if not any([i in special_char for i in password]):
        pas = False 
        
    return pas


def login():
    email = input("Enter email: ")
    if email_validation(email) == True:
        with open("credentials.txt", "r") as f:
            stored_email, stored_pwd = f.read().split("\n")
        f.close()
        if email == stored_email:    
            pwd = input("Enter password: ")
            with open("credentials.txt", "r") as f:
                stored_email, stored_pwd = f.read().split("\n")
            f.close()
            if email == stored_email and pwd == stored_pwd:
                  print("Logged in Successfully!")
            else:
                  print(" Login failed! ")
        else:
            print(" Email is not Register, Please Signup ")
    else:
        print("   Enter Valid Email address  ")


def ForgotPassword():
        email = input("Enter email: ")
        if email_validation(email) == True:
            with open("credentials.txt","r") as f:
                stored_email, stored_pwd = f.read().split()
            f.close()
            if email == stored_email: 
                print(stored_pwd)
            else:
                print(" Email is not Register, Please Signup \n")


while 1:
    print("********** Login System **********")
    print("1.Sign Up")
    print("2.Login")
    print("3.Forgot Password")
    print("4.Exit")
    ch = int(input(" Enter your choice : "))
    if ch == 1:
        signup()
    elif ch == 2:
        login()
    elif ch == 3:
        ForgotPassword()
    elif ch == 4:
        break
    else:
        print(" \n Wrong Choice! \n ")
# Out:
# ********** Login System **********
# 1.Signup
# 2.Login
# 3.Forgot Password
# 4.Exit
#  Enter your choice : 1
# Enter email address: bala@gmail.com
# Enter password: Bala@123
# Confirm password: Bala@123
#  You have registered successfully!
# ********** Login System **********
# 1.Signup
# 2.Login
# 3.Forgot Password
# 4.Exit
#  Enter your choice : 2
# Enter email: bala@gmail.com
# Enter password: Bala@123
# Logged in Successfully!
# ********** Login System **********
# 1.Signup
# 2.Login
# 3.Forgot Password
# 4.Exit
#  Enter your choice : 3
# Enter email: bala@gmail.com
# Bala@123
# ********** Login System **********
# 1.Signup
# 2.Login
# 3.Forgot Password
# 4.Exit
#  Enter your choice : 1
# Enter email address: savi@gmail.com
# Enter password: savi@123
# Confirm password: savi@123
#   Password doesn't meet the Conditions
# ********** Login System **********
# 1.Signup
# 2.Login
# 3.Forgot Password
# 4.Exit
#  Enter your choice : 4
